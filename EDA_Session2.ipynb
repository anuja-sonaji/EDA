# %% [markdown]
# ## How to read a dataframe ##

# %% [markdown]
# - Need
#     - file name, file location

# %% [markdown]
# - location is not required since  python file and data file are in same place

# %%
import pandas as pd

# %%
pd.read_csv('data1.csv')
# Out:
#        Names  Age    city
# 0     Atharv   28   Blore
# 1   Shreyash   30     Hyd
# 2  Bharghavi   31    Pune
# 3      Gauri   29  Mumbai

# %%
pd.read_excel('data2.xlsx')
# Out:
#        Names  Age    city
# 0     Atharv   28   Blore
# 1   Shreyash   30     Hyd
# 2  Bharghavi   31    Pune
# 3      Gauri   29  Mumbai

# %%
bankDataFile= pd.read_csv('C:/Users/Anuja_PC/OneDrive/Documents/dataFiles/bank - bank.csv')

# %%
bankDataFile
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
visadataFile=pd.read_csv('C:/Users/Anuja_PC/OneDrive/Documents/dataFiles/Visadataset - Visadataset.csv')

# %%
visadataFile
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
bankDataFile1= pd.read_excel("C:/Users/Anuja_PC/OneDrive/Documents/dataFiles/bank.xlsx") 
bankDataFile1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
name= ['Avinash','Akash','Adhya']
age=[25,30,35]
df=pd.DataFrame(zip(name,age),columns=['Names','Ages'])
df
# Out:
#      Names  Ages
# 0  Avinash    25
# 1    Akash    30
# 2    Adhya    35

# %%
dict1 = {'Names':['Avinash','Akash','Adhya'],'Ages':[25,30,35]} # key=columns , values = rows
pd.DataFrame(dict1)   # no need to provide column name seperatly
# Out:
#      Names  Ages
# 0  Avinash    25
# 1    Akash    30
# 2    Adhya    35

# %%
dict2={'Name':'Avinash',
       'Age':30,
      'City':'Pune'}
pd.DataFrame(dict2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 4
#       1 dict2={'Name':'Avinash',
#       2        'Age':30,
#       3       'City':'Pune'}
# ----> 4 pd.DataFrame(dict2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:733, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     727     mgr = self._init_mgr(
#     728         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     729     )
#     731 elif isinstance(data, dict):
#     732     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 733     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     734 elif isinstance(data, ma.MaskedArray):
#     735     from numpy.ma import mrecords
#
# ...

# %%
dict2={'Name':'Avinash',
       'Age':30,
      'City':'Pune'}
pd.DataFrame(dict2,index=[1])
# Out:
#       Name  Age  City
# 1  Avinash   30  Pune
