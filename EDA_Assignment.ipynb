# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as pt
import seaborn as sns

# %%
visadf=pd.read_csv('C:/Users/Anuja_PC/OneDrive/Documents/dataFiles/Visadataset.csv')
visadf
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visadf['education_of_employee']
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
employeDf = visadf['education_of_employee'].value_counts()
employeDf
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
empKeys=employeDf.keys()
empKeys
# Out:
# Index(['Bachelor's', 'Master's', 'High School', 'Doctorate'], dtype='object', name='education_of_employee')

# %%
empValues=employeDf.values
empValues
# Out:
# array([10234,  9634,  3420,  2192], dtype=int64)

# %%
employeeDf=pd.DataFrame(zip(empKeys,empValues),columns=['education_of_employee','count'])
employeeDf
# Out:
#   education_of_employee  count
# 0            Bachelor's  10234
# 1              Master's   9634
# 2           High School   3420
# 3             Doctorate   2192

# %% [markdown]
# $Bar Chart$

# %%
#pt.figure(figsize=[10,5],facecolor='#EDB120')
pt.bar("education_of_employee","count",data=employeeDf)
pt.title("Employee Bar Chart")
pt.xlabel("--------Education of employee----------")
pt.ylabel("--------count---------")
pt.savefig("barchartemp.png")

pt.show()

# %% [markdown]
# $Seaborn Bar Chart$

# %%
empKeys=employeDf.keys()
empKeys
# Out:
# Index(['Bachelor's', 'Master's', 'High School', 'Doctorate'], dtype='object', name='education_of_employee')

# %%
empKeys=employeDf.keys()
#pt.figure(figsize=[10,5],facecolor='#EDB120')
sns.countplot(data=visadf,x="education_of_employee", order=empKeys)
pt.title("Employee Seaborn Bar Chart")
pt.xlabel("--------Education of employee----------")
pt.ylabel("--------count---------")
pt.savefig("snsbarchartemp.png")

pt.show()

# %%
employeDf
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %% [markdown]
# $matplotlib$

# %%
ax=employeDf.plot(kind='bar')
ax.bar_label(ax.containers[0])
pt.show()

# %% [markdown]
# $Subplots$

# %%
pt.figure(figsize=[10,5])
pt.subplot(1,2,1)
pt.bar("education_of_employee","count",data=employeeDf)
pt.title("Employee Bar Chart")
pt.xlabel("--------Education of employee----------")
pt.ylabel("--------count---------")
pt.savefig("barchartemp.png")


edf=visadf['education_of_employee'].value_counts()
keysInOrder=edf.keys()   # keys are in order
pt.figure(figsize=[10,5])
sns.countplot(data=visadf,x='education_of_employee', order=keysInOrder)
pt.title("sns Bar chart")
pt.xlabel("--------Continents----------")
pt.ylabel("--------count---------")
pt.savefig("snsbarchart.png")

# %% [markdown]
# $Pie chart$

# %%
pt.pie(empValues, labels=empKeys, autopct='%0.3f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1c6fc3fbf50>,
# ...
#  [Text(0.3344966922241296, 1.0479083752366503, "Bachelor's"),
#   Text(-0.9261646618060718, -0.5934804286761652, "Master's"),
#   Text(0.6288833423908359, -0.9024997183729925, 'High School'),
#   Text(1.0600699942929763, -0.293686239377485, 'Doctorate')],
#  [Text(0.18245274121316157, 0.5715863864927182, '40.165%'),
#   Text(-0.5051807246214937, -0.3237165974597264, '37.810%'),
#   Text(0.3430272776677286, -0.4922725736579958, '13.422%'),
#   Text(0.5782199968870779, -0.1601924942059009, '8.603%')])

# %%
pt.pie(empValues, labels=empKeys, autopct='%0.3f%%')
pt.show()

# %% [markdown]
# $region-of-employment$

# %%
visadf= pd.read_csv(r"C:\Users\Anuja_PC\OneDrive\Documents\dataFiles\Visadataset.csv")

# %%
visadf
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
rgEmp=visadf['region_of_employment'].value_counts()
rgEmp
# Out:
# region_of_employment
# Northeast    7195
# South        7017
# West         6586
# Midwest      4307
# Island        375
# Name: count, dtype: int64

# %%
rgkeys=rgEmp.keys()
rgkeys
# Out:
# Index(['Northeast', 'South', 'West', 'Midwest', 'Island'], dtype='object', name='region_of_employment')

# %%
regionDf=pd.DataFrame(zip(rgkeys,rgEmp),columns=['region_of_employment','count'])

regionDf
# Out:
#   region_of_employment  count
# 0            Northeast   7195
# 1                South   7017
# 2                 West   6586
# 3              Midwest   4307
# 4               Island    375

# %%
pt.bar('region_of_employment', 'count',data=regionDf)
pt.title("Region Bar Chart")
pt.xlabel("--------Region of employment----------")
pt.ylabel("--------count---------")
pt.show()

# %%
rdf=visadf['region_of_employment'].value_counts()
keysInOrder=rdf.keys()   # keys are in order
pt.figure(figsize=[10,5])
sns.countplot(data=visadf,x='region_of_employment', order=keysInOrder)
pt.title("sns Bar chart")
pt.xlabel("--------Continents----------")
pt.ylabel("--------count---------")
pt.savefig("snsbarchart.png")

# %%
pt.pie(rgEmp, labels=rgkeys, autopct='%0.3f%%')
pt.show()
